# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df =pd.read_csv("D:\workspace\data\kerala_district_weather_20000.csv")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Alan\AppData\Local\Temp\ipykernel_12100\1675542181.py:5: SyntaxWarning: invalid escape sequence '\w'
#   df =pd.read_csv("D:\workspace\data\kerala_district_weather_20000.csv")

# %%
df.head()
# Out:
#     District  Temperature  Humidity  Pressure  WindSpeed  Precipitation  \
# 0  Ernakulam        31.53     68.13   1007.98       8.07           2.39
# 1  Alappuzha        35.21     66.90   1007.68       5.57           2.48
# 2     Kannur        26.98     77.65   1016.04      14.96           1.16
# 3  Kozhikode        34.03     82.53   1017.00      10.46          10.30
# 4   Thrissur        27.25     77.30   1000.64      15.69           3.62
#
#    CloudCover  DayOfYear       MonsoonPhase Weather
# 0       70.67        312  NorthEast Monsoon  Cloudy
# 1       77.33         97        Pre-Monsoon  Cloudy
# 2       73.17        346       Post-Monsoon  Cloudy
# 3       49.67        254  SouthWest Monsoon   Rainy
# 4       65.90         66       Post-Monsoon  Cloudy
